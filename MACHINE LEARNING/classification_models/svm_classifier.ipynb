# %%
#IMPORTING ALL LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("/content/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
#we have datatypes :- object,int64.float64
#There are 891  rows and 12 columns.
#There are Nan values in Age(177),Cabin(687) and Embarked(2) column.
#Survived is my target column and other columns are features.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
#suvival rate 38%
# AGe columns mean and median have low variance.(positive skewness)
#fare column has high variance.(positive skewness)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="viridis")
#we got the idea about null values in each column.
# Out:
# <Axes: >

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x="Survived",hue="Sex", palette="RdBu_r")
#more females are survived
#more men died
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(data=df,x="Survived",hue="Pclass",palette="RdBu_r")
#Third class people died more
#First class people survived more as compared to other two classes.
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(data=df,x="SibSp")
#there is maximum count of people who are single or there is no sibsp with them.
#there are less people who come with SibSp or groups.
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
sns.countplot(data=df,x="Parch")
#there is maximum count of people who are single or there is no parent or child  with them.
#there are less people who come with SibSp or groups.
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
sns.distplot(df["Age"])
#data is right skewd
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.countplot(data=df,x="Embarked",hue='Survived')
# maximum people are from south
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.boxplot(x="Pclass",y="Age",data=df)
plt.grid(True)
#In third class outlier are present above age 53 or 55.
# In second class Outliers are presnt above age between  55 to 72 also outlires below age 5.
# In class third outliers ae present above age 54 to 75.

# %%
def fillage(cols):
  age=cols[0]
  pclass=cols[1]

  if(pd.isnull(age)): # if null plcass 1 assign 38
    if(pclass==1):
      return 38
    elif(pclass==2):
      return 29
    else:
      return 24
  else:
    return age

# %%
#filing nan values
df["Age"]=df[["Age","Pclass"]].apply(fillage,axis=1)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <Axes: >

# %%
#drop Cabin column
df.drop("Cabin",axis=1,inplace=True)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
#drop na values from Embarked column.
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.info()
#reduce memory size from 83.7 kb to 83.3 kb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          889 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 83.3+ KB

# %%
df.drop(["PassengerId","Name","Ticket"],axis=1,inplace =True)

# %%
df.info()
#reduce memory size from 83.3 kb to 62.5 kb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  889 non-null    int64
#  1   Pclass    889 non-null    int64
#  2   Sex       889 non-null    object
#  3   Age       889 non-null    float64
#  4   SibSp     889 non-null    int64
#  5   Parch     889 non-null    int64
#  6   Fare      889 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 62.5+ KB

# %% [markdown]
# ###Data Preprocessing for the Model Building

# %%
x=df.iloc[:,1:] #dataframe(features)
y=df.iloc[:,0]  # target

# %%
#ColumnTransformer is a tool in scikit-learn that lets us apply different preprocessing steps to different columns of a dataset.
from sklearn.compose import ColumnTransformer   #compose → means combine / apply multiple things together
#OrdinalEncoder converts categories to integers but also treats them as ordered
from sklearn.preprocessing import OrdinalEncoder
ct = ColumnTransformer(
    transformers=[          #We are giving a list of transformations.Each transformation is written as a tuple
        (
            "encode",
            OrdinalEncoder(),
            ["Sex","Embarked"]
        )
    ],remainder="passthrough"    #All columns NOT mentioned above should stay unchanged
    )
x =ct.fit_transform(x)

# %%
x
# Out:
# array([[ 1.    ,  2.    ,  3.    , ...,  1.    ,  0.    ,  7.25  ],
#        [ 0.    ,  0.    ,  1.    , ...,  1.    ,  0.    , 71.2833],
#        [ 0.    ,  2.    ,  3.    , ...,  0.    ,  0.    ,  7.925 ],
#        ...,
#        [ 0.    ,  2.    ,  3.    , ...,  1.    ,  2.    , 23.45  ],
#        [ 1.    ,  0.    ,  1.    , ...,  0.    ,  0.    , 30.    ],
#        [ 1.    ,  1.    ,  3.    , ...,  0.    ,  0.    ,  7.75  ]])

# %%
#IMPORT MODELI to split data.
from sklearn.model_selection import  train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
#Imports K-Nearest Neighbors classifier.
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
#Trains model using training data.
knn.fit(xtrain,ytrain)
#Predicts outcomes for test data.
ypred=knn.predict(xtest)

# %%
train=knn.score(xtrain,ytrain)
test=knn.score(xtest,ytest)


print(f"training  accuracy:{train}\ntesting accuracy:{test}")
# Out:
# training  accuracy:0.7813504823151125
# testing accuracy:0.6928838951310862

# %%
# Finding optimal K value
trainac = []
testac = []

#Tests K values from 1 to 30.
for i in range(1,31):
  #Trains model for each K.
  knn=KNeighborsClassifier(n_neighbors=i)
  knn.fit(xtrain,ytrain)

  #Calculates accuracy for each K.
  train=knn.score(xtrain,ytrain)
  test=knn.score(xtest,ytest)

  #Stores results.
  trainac.append(train)
  testac.append(test)

print(f"{i}\n {train}\n {test}")


#Overfitting
# Out:
# 30
#  0.7009646302250804
#  0.6629213483146067

# %%
#Imports K-Nearest Neighbors classifier.
from sklearn.neighbors import KNeighborsClassifier
#Creates KNN model with K = 12 neighbors.
#K determines how many nearby points influence prediction.
knn=KNeighborsClassifier(n_neighbors=12)
#Trains model using training data.
knn.fit(xtrain,ytrain)
#Predicts outcomes for test data.
ypred=knn.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.77       166
#            1       0.63      0.51      0.57       101
#
#     accuracy                           0.70       267
#    macro avg       0.68      0.67      0.67       267
# weighted avg       0.70      0.70      0.70       267

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()

# %%
#To train data use .fit()
logreg.fit(xtrain,ytrain)
# Predicts car prices for test data.
ypred=logreg.predict(xtest)

# %%
#Imports evaluation metrics.
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
ac = accuracy_score(ytest,ypred)   #Calculates overall accuracy.
cm= confusion_matrix(ytest,ypred)  #Shows correct vs incorrect predictions.
cr = classification_report(ytest,ypred)   #Displays precision, recall, f1-score.

print(f"Accuracy: {ac}\{cm}\{cr}")
# Out:
# Accuracy: 0.8426966292134831\[[144  22]
#  [ 20  81]]\              precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87       166
#            1       0.79      0.80      0.79       101
#
#     accuracy                           0.84       267
#    macro avg       0.83      0.83      0.83       267
# weighted avg       0.84      0.84      0.84       267

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1,stratify=y)#dividing a dataset into subgroups based on (features and target) to ensure these proportions are maintained when splitting data

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg.fit(xtrain,ytrain)
ypred=logreg.predict(xtest)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
ac = accuracy_score(ytest,ypred)   #Calculates overall accuracy.
cm= confusion_matrix(ytest,ypred)  #Shows correct vs incorrect predictions.
cr = classification_report(ytest,ypred)   #Displays precision, recall, f1-score.

print(f"Accuracy: {ac}\{cm}\{cr}")
# Out:
# Accuracy: 0.8052434456928839\[[141  24]
#  [ 28  74]]\              precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       165
#            1       0.76      0.73      0.74       102
#
#     accuracy                           0.81       267
#    macro avg       0.79      0.79      0.79       267
# weighted avg       0.80      0.81      0.80       267

# %%
ypred=logreg.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       165
#            1       0.76      0.73      0.74       102
#
#     accuracy                           0.81       267
#    macro avg       0.79      0.79      0.79       267
# weighted avg       0.80      0.81      0.80       267

# %%
from sklearn.svm import SVC  #Finds best decision boundary
svm=SVC()
svm.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
train=svm.score(xtrain,ytrain)
test=svm.score(xtest,ytest)
print(f"training result {train}")
print(f"testing result {test}")
# Out:
# training result 0.6752411575562701
# testing result 0.6928838951310862

# %%
from sklearn.preprocessing import StandardScaler   #Scaling makes all features comparable
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
train=svm.score(xtrain,ytrain)
test=svm.score(xtest,ytest)
print(f"training result {train}")
print(f"testing result {test}")
# Out:
# training result 0.8344051446945338
# testing result 0.8389513108614233
