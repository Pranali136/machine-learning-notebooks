# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
#  READING FILES USING PANDAS

# %%
# Reading TSV file (tab-separated)
df=pd.read_table("chiporders.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
df.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
# Reading CSV file
# csv=pd.read_table('sales.csv') #It will give data in comma separated format
# df

# %%
csv=pd.read_table('sales.csv',sep=",") #this will help to form data in table format
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
csv.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M  11-07-2011  185941302  12-08-2011        3018      154.06
# 2              C  10/31/2016  246222341  12-09-2016        1517      255.28
# 3              C  04-10-2010  161442649  05-12-2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
csv.tail()
# Out:
#                            Region               Country   Item Type  \
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 995       Offline              C   4/18/2010  534085166   4/25/2010
# 996       Offline              H  08-01-2011  590768182  09-07-2011
# 997        Online              C  05-12-2011  524363124   6/28/2011
# 998       Offline              L   1/25/2016  289606320   2/14/2016
# 999       Offline              C  04-10-2014  811546599  05-08-2014
#
#      Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 995        6524      152.58      97.44      995431.92   635698.56
# ...

# %%
# Reading Excel file (default sheet)
xl=pd.read_excel('exbook.xlsx')
xl
# Out:
#    Sr.NO                                   Books            Author  year  \
# 0      1                  The Discovery of India  Jawaharlal Nehru  1946
# 1      2  The Story of my Experiments with Truth    Mahatma Gandhi  1927
# 2      3                 Glimps of World History           J.Nehru  1934
# 3      4                       A Guide to Health    Mahatma Gandhi  1921
# 4      5                           Ignited Minds   APJ Abdul Kalam  2002
# 5      6                           Wings of Fire   APJ Abdul Kalam  1999
#
#      Price  Profit
# 0   599.95    0.30
# 1   159.00    0.30
# 2   750.46    0.24
# 3   250.00    0.25
# 4   300.00    0.10
# 5  1275.25    0.10

# %%
# Reading all sheets
xl=pd.read_excel('exbook.xlsx',sheet_name=None)
xl
# Out:
# {'Sheet1':    Sr.NO                                   Books            Author  year  \
#  0      1                  The Discovery of India  Jawaharlal Nehru  1946
#  1      2  The Story of my Experiments with Truth    Mahatma Gandhi  1927
#  2      3                 Glimps of World History           J.Nehru  1934
#  3      4                       A Guide to Health    Mahatma Gandhi  1921
#  4      5                           Ignited Minds   APJ Abdul Kalam  2002
#  5      6                           Wings of Fire   APJ Abdul Kalam  1999
#
#       Price  Profit
#  0   599.95    0.30
#  1   159.00    0.30
#  2   750.46    0.24
#  3   250.00    0.25
#  4   300.00    0.10
#  5  1275.25    0.10  ,
#  'Sheet2': Empty DataFrame
#  Columns: []
#  Index: [],
#  'Sheet3': Empty DataFrame
#  Columns: []
#  Index: []}

# %%
# Reading specific sheet
xl=pd.read_excel('exbook.xlsx',sheet_name="Sheet2")
xl
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
xl.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
xl.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# READING PSV FILE (PIPE SEPARATED)
ps=pd.read_table('psd.user')
ps
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# ..                            ...
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841
#
# [942 rows x 1 columns]

# %%
ps=pd.read_table('psd.user',sep='|')
ps
# Out:
#        1  24  M     technician  85711
# 0      2  53  F          other  94043
# 1      3  23  M         writer  32067
# 2      4  24  M     technician  43537
# 3      5  33  F          other  15213
# 4      6  42  M      executive  98101
# ..   ...  .. ..            ...    ...
# 937  939  26  F        student  33319
# 938  940  32  M  administrator  02215
# 939  941  20  M        student  97229
# 940  942  48  F      librarian  78209
# 941  943  22  M        student  77841
#
# [942 rows x 5 columns]

# %%
# Adding custom column names
col=["Sr_no","Age","Gender","Profesion","Id"] #creating column header
ps=pd.read_table('psd.user',sep='|',header=None,names=col)
ps
# Out:
#      Sr_no  Age Gender      Profesion     Id
# 0        1   24      M     technician  85711
# 1        2   53      F          other  94043
# 2        3   23      M         writer  32067
# 3        4   24      M     technician  43537
# 4        5   33      F          other  15213
# ..     ...  ...    ...            ...    ...
# 938    939   26      F        student  33319
# 939    940   32      M  administrator  02215
# 940    941   20      M        student  97229
# 941    942   48      F      librarian  78209
# 942    943   22      M        student  77841
#
# [943 rows x 5 columns]

# %%
ps.head()
# Out:
#    Sr_no  Age Gender   Profesion     Id
# 0      1   24      M  technician  85711
# 1      2   53      F       other  94043
# 2      3   23      M      writer  32067
# 3      4   24      M  technician  43537
# 4      5   33      F       other  15213

# %%
ps.tail(10)
# Out:
#      Sr_no  Age Gender      Profesion     Id
# 933    934   61      M       engineer  22902
# 934    935   42      M         doctor  66221
# 935    936   24      M          other  32789
# 936    937   48      M       educator  98072
# 937    938   38      F     technician  55038
# 938    939   26      F        student  33319
# 939    940   32      M  administrator  02215
# 940    941   20      M        student  97229
# 941    942   48      F      librarian  78209
# 942    943   22      M        student  77841

# %% [markdown]
# COLUMN OPERATIONS

# %%
#column header
a=pd.read_csv('course.csv')
a
# Out:
#      1     Mumbai        PQR institute .Pvt            BI  MH   9 Months
# 0    2      Delhi    ABC institute .Pvt.LTD            AI  UP  18 Months
# 1    3  Bengaluru       MNO  institute .Ltd  Data Science  TN  11 Months
# 2    4     Bhopal   RST  institute .Pvt.LTD            ML  MP   3 Months
# 3    5     Mumbai   EFG  institute .Pvt.LTD            DL  MH   3 Months
# 4    6  Hyderabad           LMN  institute          Could  AP   4 Months
# 5    7      Patna      DEF   institute .Ltd      Web Serv  BH   4 Months
# 6    8    Channai   PQR  institute .Pvt.LTD           AWS  KT   3 Months
# 7    9    Kolkata       UVW  institute .Ltd    Networking  WB   3 Months
# 8   10  Hyderabad      GHI   institute .Ltd            AI  AP  18 Months
# 9   11     Bhopal          IJK   institute             DL  MP   3 Months
# 10  12       Pune      KLM   institute .Ltd  Data Science  MH  11 Months
# 11  13      Delhi       STU  institute .Ltd            BI  UP   6 Months
# ...

# %%
# Custom column names
col=["Sr_no","City","Institute_name","Course","State","Duration"]
a=pd.read_csv('course.csv',header=None,names=col)
a
# Out:
#     Sr_no       City            Institute_name        Course State   Duration
# 0       1     Mumbai        PQR institute .Pvt            BI    MH   9 Months
# 1       2      Delhi    ABC institute .Pvt.LTD            AI    UP  18 Months
# 2       3  Bengaluru       MNO  institute .Ltd  Data Science    TN  11 Months
# 3       4     Bhopal   RST  institute .Pvt.LTD            ML    MP   3 Months
# 4       5     Mumbai   EFG  institute .Pvt.LTD            DL    MH   3 Months
# 5       6  Hyderabad           LMN  institute          Could    AP   4 Months
# 6       7      Patna      DEF   institute .Ltd      Web Serv    BH   4 Months
# 7       8    Channai   PQR  institute .Pvt.LTD           AWS    KT   3 Months
# 8       9    Kolkata       UVW  institute .Ltd    Networking    WB   3 Months
# 9      10  Hyderabad      GHI   institute .Ltd            AI    AP  18 Months
# 10     11     Bhopal          IJK   institute             DL    MP   3 Months
# ...

# %%
# Dot notation (only works for valid column names)
a.City.head()
# Out:
# 0       Mumbai
# 1        Delhi
# 2    Bengaluru
# 3       Bhopal
# 4       Mumbai
# Name: City, dtype: object

# %%
a.Course.tail()
# Out:
# 20    Data Science
# 21              ML
# 22              DL
# 23           Could
# 24        Web Serv
# Name: Course, dtype: object

# %%
#Bracket Notation Value found
a["Institute_name"].head()
# Out:
# 0         PQR institute .Pvt
# 1     ABC institute .Pvt.LTD
# 2        MNO  institute .Ltd
# 3    RST  institute .Pvt.LTD
# 4    EFG  institute .Pvt.LTD
# Name: Institute_name, dtype: object

# %%
# Selecting multiple columns
a[["Institute_name","City","Sr_no"]].head()
# Out:
#             Institute_name       City  Sr_no
# 0       PQR institute .Pvt     Mumbai      1
# 1   ABC institute .Pvt.LTD      Delhi      2
# 2      MNO  institute .Ltd  Bengaluru      3
# 3  RST  institute .Pvt.LTD     Bhopal      4
# 4  EFG  institute .Pvt.LTD     Mumbai      5

# %% [markdown]
# FILTERING DATA

# %%
# Filtering using conditions
a[
(a['State'] == 'MH') &
    (a['City'].str.lower().isin(['mumbai']))]
a
# Out:
#     Sr_no       City            Institute_name        Course State   Duration
# 0       1     Mumbai        PQR institute .Pvt            BI    MH   9 Months
# 1       2      Delhi    ABC institute .Pvt.LTD            AI    UP  18 Months
# 2       3  Bengaluru       MNO  institute .Ltd  Data Science    TN  11 Months
# 3       4     Bhopal   RST  institute .Pvt.LTD            ML    MP   3 Months
# 4       5     Mumbai   EFG  institute .Pvt.LTD            DL    MH   3 Months
# 5       6  Hyderabad           LMN  institute          Could    AP   4 Months
# 6       7      Patna      DEF   institute .Ltd      Web Serv    BH   4 Months
# 7       8    Channai   PQR  institute .Pvt.LTD           AWS    KT   3 Months
# 8       9    Kolkata       UVW  institute .Ltd    Networking    WB   3 Months
# 9      10  Hyderabad      GHI   institute .Ltd            AI    AP  18 Months
# 10     11     Bhopal          IJK   institute             DL    MP   3 Months
# ...

# %%
# Value counts
a[a['State']=="MH"].value_counts()
# Out:
# Sr_no  City    Institute_name            Course        State  Duration
# 1      Mumbai  PQR institute .Pvt        BI            MH     9 Months     1
# 5      Mumbai  EFG  institute .Pvt.LTD   DL            MH     3 Months     1
# 12     Pune    KLM   institute .Ltd      Data Science  MH     11 Months    1
# 14     Mumbai  XYZ  institute .Pvt.LTD   Could         MH     3 Months     1
# 18     Mumbai  ZAB   institute           Web Serv      MH     4 Months     1
# 19     Pune    CDE  institute .Ltd       Data Science  MH     11 Months    1
# 23     Mumbai  XCAD  institute .Pvt.LTD  DL            MH     3 Months     1
# Name: count, dtype: int64
