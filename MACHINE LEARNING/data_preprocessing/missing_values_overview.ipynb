# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_table("/content/data1.csv",sep=",")
df
# Out:
#     name  Python    ML
# 0    jay    90.0   NaN
# 1    raj     NaN  89.0
# 2  kumar    78.0  78.0
# 3  pawan     NaN   NaN
# 4   veer     NaN  87.0
# 5  mohit    65.0  56.0
# 6    ram    45.0  67.0
# 7  dhenu    80.0  45.0
# 8   sham    70.0  67.0
# 9  madhu     NaN   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    10 non-null     object
#  1   Python  6 non-null      float64
#  2   ML      7 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 372.0+ bytes

# %%
#TO CHECK TOTAL BLANK OR NULL VALUES FROM EACH COLUMN
df.isna().sum()
# Out:
# name      0
# Python    4
# ML        3
# dtype: int64

# %%
#IT WILL DROP THE ENTIRE WHERE NAN VALUES ARE PRESENT
df.dropna()
# Out:
#     name  Python    ML
# 2  kumar    78.0  78.0
# 5  mohit    65.0  56.0
# 6    ram    45.0  67.0
# 7  dhenu    80.0  45.0
# 8   sham    70.0  67.0

# %%
np.nan
# Out:
# nan

# %%
df.dropna(how="all")
# Out:
#     name  Python    ML
# 0    jay    90.0   NaN
# 1    raj     NaN  89.0
# 2  kumar    78.0  78.0
# 3  pawan     NaN   NaN
# 4   veer     NaN  87.0
# 5  mohit    65.0  56.0
# 6    ram    45.0  67.0
# 7  dhenu    80.0  45.0
# 8   sham    70.0  67.0
# 9  madhu     NaN   NaN

# %%
df.dropna(how="all",subset=["Python","ML"])
# Out:
#     name  Python    ML
# 0    jay    90.0   NaN
# 1    raj     NaN  89.0
# 2  kumar    78.0  78.0
# 4   veer     NaN  87.0
# 5  mohit    65.0  56.0
# 6    ram    45.0  67.0
# 7  dhenu    80.0  45.0
# 8   sham    70.0  67.0

# %%
df.fillna(5)
# Out:
#     name  Python    ML
# 0    jay    90.0   5.0
# 1    raj     5.0  89.0
# 2  kumar    78.0  78.0
# 3  pawan     5.0   5.0
# 4   veer     5.0  87.0
# 5  mohit    65.0  56.0
# 6    ram    45.0  67.0
# 7  dhenu    80.0  45.0
# 8   sham    70.0  67.0
# 9  madhu     5.0   5.0

# %%
df["Python"].mean()
# Out:
# np.float64(71.33333333333333)

# %%
pmean=df["Python"].mean()
nmean=df["ML"].mean()

# %%
#TEMPORARY CHANGES
df["Python"].fillna(pmean)
df["ML"].fillna(nmean)
# Out:
# 0    69.857143
# 1    89.000000
# 2    78.000000
# 3    69.857143
# 4    87.000000
# 5    56.000000
# 6    67.000000
# 7    45.000000
# 8    67.000000
# 9    69.857143
# Name: ML, dtype: float64

# %%
#permanent changes
df["Python"].fillna(pmean,inplace=True)
df["ML"].fillna(nmean,inplace=True)

# %%
df
# Out:
#     name     Python         ML
# 0    jay  90.000000  69.857143
# 1    raj  71.333333  89.000000
# 2  kumar  78.000000  78.000000
# 3  pawan  71.333333  69.857143
# 4   veer  71.333333  87.000000
# 5  mohit  65.000000  56.000000
# 6    ram  45.000000  67.000000
# 7  dhenu  80.000000  45.000000
# 8   sham  70.000000  67.000000
# 9  madhu  71.333333  69.857143

# %%
#converting marks from float to int (if marks like 85.7, 92.4, etc. exist, you may want to round first)
# df['Python'] = df['Python'].round().astype('Int64')
df['ML'] = df['ML'].astype(int)

# %%
df
# Out:
#     name     Python  ML
# 0    jay  90.000000  69
# 1    raj  71.333333  89
# 2  kumar  78.000000  78
# 3  pawan  71.333333  69
# 4   veer  71.333333  87
# 5  mohit  65.000000  56
# 6    ram  45.000000  67
# 7  dhenu  80.000000  45
# 8   sham  70.000000  67
# 9  madhu  71.333333  69

# %%
df['ML'] = df['ML'].astype(int)

# %%
df
# Out:
#     name     Python  ML
# 0    jay  90.000000  69
# 1    raj  71.333333  89
# 2  kumar  78.000000  78
# 3  pawan  71.333333  69
# 4   veer  71.333333  87
# 5  mohit  65.000000  56
# 6    ram  45.000000  67
# 7  dhenu  80.000000  45
# 8   sham  70.000000  67
# 9  madhu  71.333333  69

# %%
df['Python'].isna().sum()
# Out:
# np.int64(0)

# %%
df = pd.read_table("/content/data2.csv",sep=",")
df
# Out:
#       name   Python   ML      Age       AI  NLP       CV
# 0      ram       90    ?       33       90    ?       33
# 1     veer  missing   89      NaN  missing   89      NaN
# 2    manoj       78   78        ?       78   78        ?
# 3     sham      NaN  NaN  missing      NaN  NaN  missing
# 4    dheru  missing  NaN       21  missing  NaN       21
# 5  mangesh       65   56       22       65   56       22
# 6   pritam       45   67        ?       45   67        ?
# 7   neveen       80   45       24       80   45       24
# 8     rano       70   67  missing       70   67  missing
# 9     mona      NaN  NaN       22      NaN  NaN       22

# %%
# df.isna().sum()

# %%
# pmean=df["Python"].mean()
# nmean=df["ML"].mean()

# %%
#permanent changes
# df["Python"].fillna(pmean,inplace=True)
# df["ML"].fillna(nmean,inplace=True)
